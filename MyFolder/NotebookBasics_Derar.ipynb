# %%
print("Hello World")

# %%
# %sql
select 'Hellow'

# %% [markdown]
# # this is title 1
# ### This is title 3

# %%
# %run ./Includes/variables

# %%
print(name)

# %%
# %fs ls '/databricks-datasets'

# %%
f = dbutils.fs.ls('/databricks-datasets')
display(f)
